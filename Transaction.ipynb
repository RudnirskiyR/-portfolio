# %% [markdown]
# Транзакции

# %% [markdown]
# Датасет https://www.kaggle.com/mlg-ulb/creditcardfraud.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
data = pd.read_csv('creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# V24       284807 non-null float64
# V25       284807 non-null float64
# V26       284807 non-null float64
# V27       284807 non-null float64
# V28       284807 non-null float64
# Amount    284807 non-null float64
# Class     284807 non-null int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.shape
# Out:
# (284807, 31)

# %%
sns.heatmap(data.corr() ,annot = False,cmap="YlGnBu",linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(15,15)
plt.show()

# %%
plt.hist(data['Class'])
plt.show()

# %%
df = pd.get_dummies(data, columns = ['Class'],
                             prefix=['Class'])

# %%
df.head(2)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
#
#         V27       V28  Amount  Class_0  Class_1
# 0  0.133558 -0.021053  149.62        1        0
# 1 -0.008983  0.014724    2.69        1        0
#
# [2 rows x 32 columns]

# %%
df = df.rename({'Class_0': 'normal','Class_1': 'hacked' }, axis=1)

# %%
df.head(1)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
#
#         V27       V28  Amount  normal  hacked
# 0  0.133558 -0.021053  149.62       1       0
#
# [1 rows x 32 columns]

# %%
fig, axs = plt.subplots(ncols=4, nrows=8, figsize=(25, 40))
index = 0
axs = axs.flatten()
for k,v in df.items():
    sns.distplot(v, ax=axs[index])
    index += 1
plt.tight_layout()
plt.show()

# %%
count_hacked = df.hacked.sum()
count_normal = df.normal.sum()
print(count_hacked)
print(count_normal)
print(df.hacked.sum()/df.normal.sum()*100)
# Out:
# 492
# 284315
# 0.17304750013189596

# %%
hacked_transacation = df[df['hacked']==1]
Normal_transacation= df[df['normal']==0]
plt.figure(figsize=(10,6))
plt.subplot(121)
hacked_transacation.Amount.plot.hist(title="Hacked Transacation")
plt.subplot(122)
Normal_transacation.Amount.plot.hist(title="Normal Transaction")

# %% [markdown]
# Приведем оба графика к общему виду

# %%
df[df['hacked'] == 1].max()['Amount']
# Out:
# 2125.87

# %%
hacked_transacation = df[df['hacked']==1]
normal_transacation= df[df['normal']==1]
plt.figure(figsize=(10,6))
plt.subplot(121)
hacked_transacation[hacked_transacation['Amount'] <= 2125.87].Amount.plot.hist(title="Hacked Transacation")
plt.subplot(122)
normal_transacation[normal_transacation['Amount'] <= 2125.87].Amount.plot.hist(title="Normal transacation")

# %% [markdown]
# Исходя из этого графика можно сделать вывод что:<br>
#     1.Большинство транзакций приходятся на небольшие суммы ( что очевидно)<br>
#     2.Графики крайне похожи, потому невозможно однозначно выделить различия между мошеничискими транзакциями и нормальными.<br>
#     3.Отсутсвует закономерность, позволяющая сделать выводы

# %%
from sklearn.linear_model import LinearRegression
class_ = data['Class']
amount = data['Amount']
model = LinearRegression()
result = model.fit(np.array(class_).reshape(-1,1), amount)

print('intercept:', model.intercept_)

print('slope:', model.coef_)
# Out:
# intercept: 88.29102242231325
# slope: [33.92029872]

# %%
plt.xlabel('class_')
plt.ylabel('amount')
plt.title('Линейная регрессия')
x = np.linspace(min(class_), max(class_), 100)
y = model.coef_*x + model.intercept_
plt.plot(x,y)
plt.plot(class_,amount, 'b.')
plt.show()

# %%
Hacked = data[data['Class'] == 1 ]['V7']
Normal = data[data['Class'] == 0 ]['V7'][:492]
stats.ttest_rel(Hacked, Normal)
# Out:
# Ttest_relResult(statistic=-17.090207707460504, pvalue=1.0014252297984936e-51)

# %%
Hacked = data[data['Class'] == 1 ]['Time']
Normal = data[data['Class'] == 0 ]['Time'][:492]
stats.ttest_rel(Hacked, Normal)
# Out:
# Ttest_relResult(statistic=37.443902211278456, pvalue=5.476713191285245e-146)

# %% [markdown]
# Я попровобал разные тесты,разные переменные но результат везде один и  тот же. P-value меньше нуля, различий нет

# %% [markdown]
# Поэтому попробуем сравнить выборку нормальных значений с мошенеческими.

# %%
data1 = data[data['Class'] == 1]
len(data1)
data_ = data[data['Class'] == 0]
data2 = data_.sample(n = 492) 
len(data2)
union_data = pd.concat([data1, data2])
len(union_data)
# Out:
# 984

# %% [markdown]
# Для чистоты эксперимент я использовал sample, чтоб выбрать случайный набор данных

# %%
union_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 267099  162608.0  2.075365  0.058177 -1.094044  0.366441  0.063855 -1.093823
# 147443   88559.0 -0.406077  0.848183  1.300761 -0.077862  0.601854 -0.485250
# 265130  161753.0  2.008547 -0.140687 -1.094456  0.428848 -0.144643 -1.123234
# 65960    51824.0 -0.528263  0.766561  1.347913 -0.568667  0.969786 -0.677903
# 221239  142487.0 -1.292473  0.770150  2.029403 -2.177584 -0.749404 -1.417272
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 267099  0.283209 -0.411376  0.322498  ... -0.282048 -0.601842  0.304516
# 147443  1.328158 -0.399037 -0.519730  ... -0.282503 -0.589417 -0.332337
# 265130  0.193784 -0.309224  0.553135  ... -0.270535 -0.696288  0.327753
# 65960   0.936243 -0.270503 -0.307834  ... -0.287791 -0.795634 -0.178592
# 221239  0.329621  0.366122  0.081375  ... -0.073916 -0.461909 -0.069328
#
#              V24       V25       V26       V27       V28  Amount  Class
# 267099 -0.068961 -0.227174  0.200096 -0.060877 -0.058322    0.99      0
# 147443 -0.142345  0.438304  0.563846 -0.183799 -0.174683   28.95      0
# 265130 -0.014900 -0.325510  0.198939 -0.072627 -0.056683   24.99      0
# 65960  -0.509650 -0.134800 -0.041857 -0.118809 -0.103915    1.98      0
# 221239  0.880607  0.155362  0.420789 -0.184993 -0.021960   11.79      0
#
# [5 rows x 31 columns]

# %%
sns.heatmap(union_data.corr() ,annot = False,cmap="YlGnBu",linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(15,15)
plt.show()

# %% [markdown]
# И тут свершилось, "алкоголики называют это момент истины"
#
# Уберем элементы со слабой корреляцией

# %%
corr_matrix = union_data.corr().abs().iloc[:,:30]
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
to_drop = [column for column in upper.columns if any(upper[column] < 0.1)]
print(to_drop)
# Out:
# ['V6', 'V8', 'V9', 'V10', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']

# %%
sample_data = union_data.drop(union_data[to_drop], axis=1)
sample_data.head()
len(sample_data)
# Out:
# 984

# %%
sns.heatmap(sample_data.corr() ,annot = True,cmap="YlGnBu",linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(15,15)
plt.show()

# %% [markdown]
# Как видно из графика, класс больше всего коррелирует с V11, V4 и V2

# %%
hacked = sample_data[sample_data['Class'] == 1 ]['V4']
normal = sample_data[sample_data['Class'] ==  0 ]['V4']
stats.ttest_rel(hacked, normal)
# Out:
# Ttest_relResult(statistic=31.002046291194684, pvalue=1.0807552655530179e-117)

# %% [markdown]
# Показалось. Все еще нет различий

# %%
_0 = sample_data[sample_data['Class'] == 1 ]['V4']
_1 = sample_data[sample_data['Class'] == 0 ]['V4']
_2 = sample_data[sample_data['Class'] == 1 ]['V11']
_3 = sample_data[sample_data['Class'] == 0 ]['V11']
_4 = sample_data[sample_data['Class'] == 1 ]['V2']
_5 = sample_data[sample_data['Class'] == 0 ]['V2']

stats.f_oneway(_0, _1, _2,_3, _4, _5)
# Out:
# F_onewayResult(statistic=358.71980320910876, pvalue=6.447239448180425e-301)

# %%
sns.distplot(hacked)
sns.distplot(normal)
plt.title('V4')
plt.show()

# %%
fig, axs = plt.subplots(ncols=3, nrows=4, figsize=(15, 10))
index = 0
hacked = sample_data[sample_data['Class'] == 1 ]
normal = sample_data[sample_data['Class'] == 0 ]
axs = axs.flatten()
for i in range(len(hacked.columns)):
    sns.distplot(hacked.iloc[:,i:i+1], ax=axs[index])
    axs[i].set_title(hacked.columns[i])
    sns.distplot(normal.iloc[:,i:i+1], ax=axs[index])
    plt.tight_layout()
    index += 1

plt.show()

# %% [markdown]
# Анализируя график, видно что графики с мошенеческими схемами имеют более сплюснутый вид

# %%
sample_data.head(1)
# Out:
#       Time        V1        V2        V3        V4        V5        V7  \
# 541  406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -2.537387
#
#           V11       V12  Class
# 541  3.202033 -2.899907      1

# %%
V1 = sample_data['V1']
V2 = sample_data['V2']
V3 = sample_data['V3']
V4 = sample_data['V4']
V5 = sample_data['V5']
chol = sample_data['Class']
x = np.vstack([np.array(V1), np.array(V2),np.array(V3),np.array(V4),np.array(V5)]).T
print(x[:3])
y = np.array(chol)
model = LinearRegression().fit(x, y)
# Out:
# [[-2.31222654  1.95199201 -1.60985073  3.99790559 -0.52218786]
#  [-3.04354062 -3.15730712  1.08846278  2.28864362  1.35980513]
#  [-2.30334957  1.75924746 -0.35974474  2.33024305 -0.82162833]]

# %%
sample_data.iloc[100:984:150]
# Out:
#             Time        V1        V2        V3        V4        V5        V7  \
# 30496    35953.0 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -6.311699
# 123141   76826.0 -6.616293  3.563428 -7.058901  4.284346 -5.096299 -4.937554
# 215132  139951.0 -2.921944 -0.228062 -5.877289  2.201884 -1.935440 -1.245106
# 9673     14456.0  1.116287 -0.307350  0.795992  0.134097 -0.606532 -0.850000
# 65329    51531.0 -0.902407  0.041883  1.064473 -2.218291  0.754025  0.373296
# 99301    67056.0 -0.946245  1.679121  1.303640  0.719076  0.322194  1.493882
#
#              V11       V12  Class
# 30496   3.657350 -7.781448      1
# 123141  3.259595 -6.943891      1
# 215132  4.229154 -5.292314      1
# 9673    2.407370 -2.707548      0
# 65329   0.673177 -0.506294      0
# 99301   0.211313 -0.275558      0

# %%
model.predict(x[100:984:150])
# Out:
# array([0.80164746, 0.68821379, 0.52753244, 0.23170582, 0.01519987,
#        0.29845097])

# %% [markdown]
# Модель предсказывает результат не так точно, как хотелось бы, но это уже часть успеха. Сравнивая с таблицей, мы видим, что мошенеческие транзакции ближе к 1 чем нормальные.
